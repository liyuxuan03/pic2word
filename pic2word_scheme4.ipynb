# %% [markdown]
# # MintPy Word Auto Report（方案四）
#
# 本 notebook 同时支持两种配置模式：
#
# - `report_quickstart.yaml`：给新手快速修改
# - `report_schema.yaml`：给高级用户完全自定义
#
# 默认使用 `report_quickstart.yaml`。

# %%
import os
from utils import build_report_and_save

# False: 使用简版配置 report_quickstart.yaml
# True : 使用高级配置 report_schema.yaml
USE_ADVANCED_SCHEMA = True

CONFIG_PATH = os.path.join(
    os.getcwd(),
    'report_schema_scheme4.yaml' if USE_ADVANCED_SCHEMA else 'report_quickstart_scheme4.yaml'
)

print('当前配置文件：', CONFIG_PATH)
output_path, ctx = build_report_and_save(CONFIG_PATH)
print('输出文件：', output_path)
print('配置模式：', ctx.get('config', {}).get('_config_mode', 'unknown'))
# Out:
# 当前配置文件： /penguin/liyuxuan/pic2word/v4_plus/report_schema_scheme4.yaml
# 请输入封面信息 ：
# ------------------------------
# 参数设置完成：
# 数据源: Sentinel-1
# 地区: 北京
# 第一作者: yourname
# ------------------------------
# ------------------------------
# [成功] 文档已生成: /home/liyuxuan/penguin/pic2word/vision_2/word/北京InSAR处理报告.docx
# 操作提示：请打开 Word 文档，在目录页【右键 -> 更新域 -> 更新整个目录】
# ------------------------------
# 输出文件： /home/liyuxuan/penguin/pic2word/vision_2/word/北京InSAR处理报告.docx
# 配置模式： advanced
